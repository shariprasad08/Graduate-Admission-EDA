# %% [markdown]
# This dataset is created for prediction of Graduate Admissions from an Indian perspective.
#
# 1. GRE Scores ( 290 of 340 )
# 2. TOEFL Scores ( 92 of 120 )
# 3. University Rating ( 1 of 5 )
# 4. Statement of Purpose ( 1 of 5 )
# 5. Letter of Recommendation Strength ( 1 of 5 )
# 6. Undergraduate GPA ( 6.8 of 10 )
# 7. Research Experience ( 0 or 1 )
# 8. Chance of Admit ( ranging from  0.34 to 0.97)

# %% [markdown]
# # Load the Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the dataset(Graduate Admission.csv)

# %%
Data = pd.read_csv("admission_data.csv")

# %%
Data.head()                                                                                  #view the first 5 rows of the data.
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %% [markdown]
# # Check the Dimension of the Data

# %%
Data.shape                                                                                          # see the shape of the data.
# Out:
# (500, 8)

# %% [markdown]
# There are 500 Observations/rows and 8 attributes/columns.

# %% [markdown]
# # Check the information about the data and the datatypes of each

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %% [markdown]
# # EDA Descriptive statistics

# %% [markdown]
# Mean

# %%
print("Data",Data.mean())                                                                    # print the mean of each attribute.
# Out:
# Data GRE Score            316.47200
# TOEFL Score          107.19200
# University Rating      3.11400
# SOP                    3.37400
# LOR                    3.48400
# CGPA                   8.57644
# Research               0.56000
# Chance of Admit        0.72174
# dtype: float64

# %%
print("Data",Data.median())                                                                 # print the median of the attributr.
# Out:
# Data GRE Score            317.00
# TOEFL Score          107.00
# University Rating      3.00
# SOP                    3.50
# LOR                    3.50
# CGPA                   8.56
# Research               1.00
# Chance of Admit        0.72
# dtype: float64

# %%
print(Data['GRE Score'].mode())                                                               # print the mode of the attributr.
# Out:
# 0    312
# Name: GRE Score, dtype: int64

# %% [markdown]
# # Quantile 25%

# %%
print("Data_quantile(25%):",Data.quantile(q=0.25))                            #print the value below which 25% of the data lies.
# Out:
# Data_quantile(25%): GRE Score            308.0000
# TOEFL Score          103.0000
# University Rating      2.0000
# SOP                    2.5000
# LOR                    3.0000
# CGPA                   8.1275
# Research               0.0000
# Chance of Admit        0.6300
# Name: 0.25, dtype: float64

# %% [markdown]
# # Quantile 50%

# %%
print("Data_quantile(50%):",Data.quantile(q=0.50))                            #print the value below which 50% of the data lies.
# Out:
# Data_quantile(50%): GRE Score            317.00
# TOEFL Score          107.00
# University Rating      3.00
# SOP                    3.50
# LOR                    3.50
# CGPA                   8.56
# Research               1.00
# Chance of Admit        0.72
# Name: 0.5, dtype: float64

# %% [markdown]
# # Quantile 75%

# %%
print("Data_quantile(75%):",Data.quantile(q=0.75))                            #print the value below which 50% of the data lies.
# Out:
# Data_quantile(75%): GRE Score            325.00
# TOEFL Score          112.00
# University Rating      4.00
# SOP                    4.00
# LOR                    4.00
# CGPA                   9.04
# Research               1.00
# Chance of Admit        0.82
# Name: 0.75, dtype: float64

# %% [markdown]
# # Plotting the summery mean,mode,median using histogram

# %%
mean = Data['GRE Score'].mean()
median = Data['GRE Score'].median()
mode = Data['GRE Score'].mode()

print('Mean: ', mean, '\nMedian: ', median, '\nMode: ', mode[0])
# Out:
# Mean:  316.472
# Median:  317.0
# Mode:  312

# %%
plt.figure(figsize=(10,5))
plt.hist(Data['GRE Score'],bins=100, color='lightblue')
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0.,  1.,  0.,  2.,  0.,  5.,  0.,  5.,
#          0.,  6.,  0., 10.,  0., 10.,  0., 12.,  0., 11.,  0.,  7.,  0.,
#          5.,  0., 12.,  0., 11.,  0.,  7.,  0., 10.,  0., 13.,  0.,  9.,
#          0., 11.,  0., 16.,  0., 24.,  0., 12.,  0., 16.,  0., 13.,  0.,
#         18.,  0., 15.,  0., 12.,  0., 12.,  0., 16.,  0., 17.,  0., 17.,
#          0., 13.,  0., 23.,  0., 15.,  0., 12.,  0., 17.,  0.,  9.,  0.,
#         10.,  0.,  8.,  0.,  9.,  0.,  8.,  0.,  4.,  0.,  8.,  0.,  4.,
#          0.,  5.,  0.,  2.,  0.,  4.,  0.,  3.,  9.]),
#  array([290. , 290.5, 291. , 291.5, 292. , 292.5, 293. , 293.5, 294. ,
#         294.5, 295. , 295.5, 296. , 296.5, 297. , 297.5, 298. , 298.5,
#         299. , 299.5, 300. , 300.5, 301. , 301.5, 302. , 302.5, 303. ,
#         303.5, 304. , 304.5, 305. , 305.5, 306. , 306.5, 307. , 307.5,
#         308. , 308.5, 309. , 309.5, 310. , 310.5, 311. , 311.5, 312. ,
#         312.5, 313. , 313.5, 314. , 314.5, 315. , 315.5, 316. , 316.5,
#         317. , 317.5, 318. , 318.5, 319. , 319.5, 320. , 320.5, 321. ,
#         321.5, 322. , 322.5, 323. , 323.5, 324. , 324.5, 325. , 325.5,
#         326. , 326.5, 327. , 327.5, 328. , 328.5, 329. , 329.5, 330. ,
#         330.5, 331. , 331.5, 332. , 332.5, 333. , 333.5, 334. , 334.5,
#         335. , 335.5, 336. , 336.5, 337. , 337.5, 338. , 338.5, 339. ,
#         339.5, 340. ]),
#  <BarContainer object of 100 artists>)

# %%
plt.figure(figsize=(10, 5))
plt.hist(Data['GRE Score'], bins=100, color='lightblue')

plt.axvline(mean, color='green', label='Mean')
plt.axvline(median, color='blue', label='Median')
if len(mode) >= 2:
    plt.axvline(mode[1], color='red', label='Mode2')
plt.axvline(mode[0], color='red', label='Mode1')

plt.xlabel('GRE Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# # Check the Data Description

# %%
Data.describe()                                                # the output results provide the five number summary of the data.
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# 50%      8.560000    1.000000           0.72000
# 75%      9.040000    1.000000           0.82000
# max      9.920000    1.000000           0.97000

# %% [markdown]
# # IQR Value for TOEFL Score

# %%
Data["TOEFL Score"].quantile(0.75)-Data["TOEFL Score"].quantile(0.25)
# Out:
# 9.0

# %% [markdown]
# # Undestanding the summary of Statistics plotting Box plots
#  five number summary

# %%
Data.boxplot(column="TOEFL Score",return_type='axes',figsize=(8,8))                    # Create boxplot for column="TOEFL Score"

                                        # create text(x=0.74, y=22.25, s="3rd Quartile")like Median, 1st Quartile,Min,Max,IQR:
plt.text(x=0.74, y=112.00, s="3rd Quartile")
plt.text(x=0.8, y=107.00, s="Median")
plt.text(x=0.75, y=103.00, s="1st Quartile")
plt.text(x=0.9, y=92.00, s="Min")
plt.text(x=0.9, y=120.00, s="Max")
plt.text(x=0.7, y=107.5, s="IQR", rotation=90, size=25)
# Out:
# Text(0.7, 107.5, 'IQR')

# %% [markdown]
# we can observe from above graph that there are no extreme values / outliers.the data was equally distributed .

# %% [markdown]
# # Check the Measures of Dispersion:

# %% [markdown]
# IQR

# %%
Data.quantile(0.75) - Data.quantile(0.25)
# Out:
# GRE Score            17.0000
# TOEFL Score           9.0000
# University Rating     2.0000
# SOP                   1.5000
# LOR                   1.0000
# CGPA                  0.9125
# Research              1.0000
# Chance of Admit       0.1900
# dtype: float64

# %% [markdown]
# the above output represents the IQR values for all the attributes.

# %% [markdown]
# # Range

# %%
print(Data.max()-Data.min())
# Out:
# GRE Score            50.00
# TOEFL Score          28.00
# University Rating     4.00
# SOP                   4.00
# LOR                   4.00
# CGPA                  3.12
# Research              1.00
# Chance of Admit       0.63
# dtype: float64

# %% [markdown]
# the above represents the difference between the highest value and lowest values for all individual attributes.

# %% [markdown]
# # Variance

# %%
print(Data.var())
# Out:
# GRE Score            127.580377
# TOEFL Score           36.989114
# University Rating      1.307619
# SOP                    0.982088
# LOR                    0.856457
# CGPA                   0.365799
# Research               0.246894
# Chance of Admit        0.019921
# dtype: float64

# %% [markdown]
# the above output says how much was the data dispersion.

# %% [markdown]
# # Standard Deviation

# %%
print(Data.std())
# Out:
# GRE Score            11.295148
# TOEFL Score           6.081868
# University Rating     1.143512
# SOP                   0.991004
# LOR                   0.925450
# CGPA                  0.604813
# Research              0.496884
# Chance of Admit       0.141140
# dtype: float64

# %% [markdown]
# the above output says how much the data deviated from the mean.

# %% [markdown]
# # Check Covariance and Correlation

# %% [markdown]
# Covariance

# %%
Data.cov()
# Out:
#                     GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score          127.580377    56.825026           8.206605  6.867206
# TOEFL Score         56.825026    36.989114           4.519150  3.883960
# University Rating    8.206605     4.519150           1.307619  0.825014
# SOP                  6.867206     3.883960           0.825014  0.982088
# LOR                  5.484521     3.048168           0.644112  0.608701
# CGPA                 5.641944     2.981607           0.487761  0.426845
# Research             3.162004     1.411303           0.242645  0.200962
# Chance of Admit      1.291862     0.680046           0.111384  0.095691
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          5.484521  5.641944  3.162004          1.291862
# TOEFL Score        3.048168  2.981607  1.411303          0.680046
# University Rating  0.644112  0.487761  0.242645          0.111384
# SOP                0.608701  0.426845  0.200962          0.095691
# LOR                0.856457  0.356807  0.171303          0.084296
# CGPA               0.356807  0.365799  0.150655          0.075326
# Research           0.171303  0.150655  0.246894          0.038282
# Chance of Admit    0.084296  0.075326  0.038282          0.019921

# %% [markdown]
# Prints the covariance of each attribute against every other attribute

# %% [markdown]
# # Correlation

# %%
Data.corr()                                               # prints the correlation coefficient between every pair of attributes.
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.827200           0.635376  0.613498
# TOEFL Score         0.827200     1.000000           0.649799  0.644410
# University Rating   0.635376     0.649799           1.000000  0.728024
# SOP                 0.613498     0.644410           0.728024  1.000000
# LOR                 0.524679     0.541563           0.608651  0.663707
# CGPA                0.825878     0.810574           0.705254  0.712154
# Research            0.563398     0.467012           0.427047  0.408116
# Chance of Admit     0.810351     0.792228           0.690132  0.684137
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.524679  0.825878  0.563398          0.810351
# TOEFL Score        0.541563  0.810574  0.467012          0.792228
# University Rating  0.608651  0.705254  0.427047          0.690132
# SOP                0.663707  0.712154  0.408116          0.684137
# LOR                1.000000  0.637469  0.372526          0.645365
# CGPA               0.637469  1.000000  0.501311          0.882413
# Research           0.372526  0.501311  1.000000          0.545871
# Chance of Admit    0.645365  0.882413  0.545871          1.000000

# %% [markdown]
# # Pairplot for checking the correlation?

# %%
import seaborn as sns

sns.pairplot(Data, kind='reg')              # plots scatter plots for every pair of attributes and histograms along the diagonal
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# * Here we can see that TOEFL, GRE and CGPA Scores highly correlate with the chance of admission
# * All of the attributes have good correlation with the chance of admission
# * Apart from the target variable, there is fair amount of correlation amongst the other variables

# %% [markdown]
# # Heatmap For checking the correlation?

# %%
fig,ax = plt.subplots(figsize=(10,10))
sns.heatmap(Data.corr(),ax=ax, annot=True, linewidths=0.05, fmt=' .2f',cmap='magma')           # the color intensity is based on
plt.show()

# %% [markdown]
# we can confirm that TOEFL Score has highest postive co-relation with all the attributes.

# %% [markdown]
# # Check the Skewness and Kurtosis

# %% [markdown]
# * Positively skewed: Most frequent values are low and tail is towards high values.
#
# * Negatively skewed: Most frequent values are high and tail is towards low values.
#
# * If Mode< Median< Mean then the distribution is positively skewed.
#
# * If Mode> Median> Mean then the distribution is negatively skewed.

# %%
Data.skew()                                                                        # to measure the skeweness of every attribute
# Out:
# GRE Score           -0.039842
# TOEFL Score          0.095601
# University Rating    0.090295
# SOP                 -0.228972
# LOR                 -0.145290
# CGPA                -0.026613
# Research            -0.242475
# Chance of Admit     -0.289966
# dtype: float64

# %% [markdown]
# # Histogram for checking the Skewness

# %%
import scipy.stats as stats 

# Convert pandas DataFrame object to numpy array and sort
h = np.asarray(Data['GRE Score'])
h = sorted(h)

# Use the scipy stats module to fit a normal distribution with the same mean and standard deviation
fit = stats.norm.pdf(h, np.mean(h), np.std(h))

# Plot both series on the histogram
plt.plot(h, fit, '-', linewidth=2, label="Normal distribution with same mean and var")
plt.hist(h, density=True, bins=100, label="Actual distribution")
plt.legend()
plt.show()

# %% [markdown]
# We can see int the above graph that it is negative skewed with skewness score -0.06 and also has Negative kurtosis(k=-0.70)
